# %% [markdown]
# <a href="https://colab.research.google.com/github/AnuragJha003/SpotifyTop100/blob/main/SpotifyTop100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### IMPORTING THE REQUIRED PACKAGES

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
sns.set_style("whitegrid")

# %% [markdown]
# ## LOADING THE REQUIRED DATASET

# %%
df=pd.read_csv("/content/SpotifyFeatures.csv")

# %%
df.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# 1       137373   0.737             0.000  F#    0.1510    -5.559  Minor
# 2       170267   0.131             0.000   C    0.1030   -13.879  Minor
# 3       152427   0.326             0.000  C#    0.0985   -12.178  Major
# 4        82625   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %%
df.describe()
# Out:
#           popularity   acousticness   danceability   duration_ms  \
# count  232725.000000  232725.000000  232725.000000  2.327250e+05
# mean       41.127502       0.368560       0.554364  2.351223e+05
# std        18.189948       0.354768       0.185608  1.189359e+05
# min         0.000000       0.000000       0.056900  1.538700e+04
# 25%        29.000000       0.037600       0.435000  1.828570e+05
# 50%        43.000000       0.232000       0.571000  2.204270e+05
# 75%        55.000000       0.722000       0.692000  2.657680e+05
# max       100.000000       0.996000       0.989000  5.552917e+06
#
#               energy  instrumentalness       liveness       loudness  \
# count  232725.000000     232725.000000  232725.000000  232725.000000
# mean        0.570958          0.148301       0.215009      -9.569885
# std         0.263456          0.302768       0.198273       5.998204
# min         0.000020          0.000000       0.009670     -52.457000
# 25%         0.385000          0.000000       0.097400     -11.771000
# 50%         0.605000          0.000044       0.128000      -7.762000
# 75%         0.787000          0.035800       0.264000      -5.501000
# max         0.999000          0.999000       1.000000       3.744000
#
#          speechiness          tempo        valence
# count  232725.000000  232725.000000  232725.000000
# mean        0.120765     117.666585       0.454917
# std         0.185518      30.898907       0.260065
# min         0.022200      30.379000       0.000000
# 25%         0.036700      92.959000       0.237000
# 50%         0.050100     115.778000       0.444000
# 75%         0.105000     139.054000       0.660000
# max         0.967000     242.903000       1.000000

# %%
print(df.keys())
#all the key values present in the dataset
# Out:
# Index(['genre', 'artist_name', 'track_name', 'track_id', 'popularity',
#        'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence'],
#       dtype='object')

# %% [markdown]
# ## DATA CLEANING

# %%
pd.isnull(df).sum() # No null values :)
# Out:
# genre               0
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# dtype: int64

# %% [markdown]
# ## EDA(EXPLORATORY DATA ANALYSIS)

# %%
sns.distplot(df['popularity']).set_title('Popularity Distribution')
#to get an idea of how different variables and attributes correlate with each other
# Out:
# <ipython-input-55-d96e110141c4>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['popularity']).set_title('Popularity Distribution')
# Text(0.5, 1.0, 'Popularity Distribution')

# %%
sns.barplot(x = 'time_signature', y = 'popularity', data = df)
plt.title('Popularity Based on Time Signature') #analysisng popularity based on time in form of barplot
# Out:
# Text(0.5, 1.0, 'Popularity Based on Time Signature')

# %%
sns.barplot(x = 'key', y = 'popularity', data = df)
plt.title('Popularity Based on Key')
# Out:
# Text(0.5, 1.0, 'Popularity Based on Key')

# %%
sns.barplot(x = 'mode', y = 'popularity', hue = 'key', data = df)
plt.title('Popularity Based on Mode and Key')
# Out:
# Text(0.5, 1.0, 'Popularity Based on Mode and Key')

# %% [markdown]
# ## FEATURE ENGINEERING

# %%
#CONVERT THE KEY TIME SIGNATURE AND MODE TO NUMBERS USING ONE HOT ENCODING
list_of_keys = df['key'].unique()
for i in range(len(list_of_keys)):
    df.loc[df['key'] == list_of_keys[i], 'key'] = i
df.sample(5)
# Out:
#                    genre             artist_name  \
# 74186   Children's Music  Kimbo Children's Music
# 145529              Jazz           Sonny Rollins
# 161189         Reggaeton          Jowell & Randy
# 18460              Dance                 A*Teens
# 98267   Children’s Music          Barns Courtney
#
#                                                track_name  \
# 74186      We've Got a Song (Bright 4/4) [Musical Comedy]
# 145529                                God Bless the Child
# 161189         Adicta al Perreo (feat. Polaco & Lui-G 21)
# 18460   Can't Help Falling In Love - From "Lilo & Stit...
# 98267                                             Sinners
#
#                       track_id  popularity  acousticness  danceability  \
# 74186   1T0hQMkSEx9FFRQ2OCPf2o           0        0.5680         0.560
# 145529  5Uftxvqqbi70QdCpLb0fKu          59        0.9190         0.480
# 161189  2lmyNNgl9zwhO6FLp7t943          35        0.1420         0.739
# 18460   6zLXWVAskybBaM2L5rCxiG          45        0.0105         0.647
# 98267   0eUgkunDciOOiao9Sjw3PW          55        0.1220         0.500
#
#         duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 74186        125000  0.3630           0.00176   2    0.0646   -10.163  Major
# 145529       445240  0.0685           0.00513   8    0.0766   -17.100  Major
# 161189       293867  0.8810           0.00000   0    0.1000    -3.487  Minor
# 18460        187507  0.8140           0.00361  11    0.3660    -9.377  Major
# 98267        173773  0.8540           0.00000   4    0.0794    -5.151  Minor
#
#         speechiness    tempo time_signature  valence
# 74186        0.0854  173.236            4/4    0.892
# 145529       0.0345  102.546            4/4    0.142
# 161189       0.1240  161.978            4/4    0.856
# 18460        0.0429  117.979            4/4    0.784
# 98267        0.0945   94.960            4/4    0.404

# %%
df.loc[df["mode"] == 'Major', "mode"] = 1
df.loc[df["mode"] == 'Minor', "mode"] = 0
df.sample(5)
#for mode we are assigning major as 1 and minor as 0
# Out:
#          genre           artist_name              track_name  \
# 131747  Reggae       The Expendables               Let Loose
# 195953   Movie  Idoles De La Musique   Les murs de poussière
# 174356  Comedy          Hasan Minhaj  The Cancer Curing Baby
# 32714    Anime            Nogizaka46      Kizuitara Kataomoi
# 212        R&B           bLAck pARty                   Bloom
#
#                       track_id  popularity  acousticness  danceability  \
# 131747  59BEsKQzbgLaUbat8LftVY          36        0.0886         0.608
# 195953  1MPW2aAOkttJ2i8ZQyALXH           6        0.5600         0.670
# 174356  4vLdgRkdrlSgz3T4QJgPkR          15        0.7630         0.632
# 32714   0RDB8WXAa97sTsc9VwXVU8          28        0.6640         0.657
# 212     05xA64s3UzOOmAnh9SIIjn          61        0.2610         0.749
#
#         duration_ms  energy  instrumentalness key  liveness  loudness mode  \
# 131747       224093   0.750           0.00113   4    0.1050    -7.143    1
# 195953       167259   0.782           0.00000   8    0.1640    -6.554    0
# 174356       213854   0.421           0.00000   3    0.7700    -9.819    1
# 32714        254827   0.757           0.00000   8    0.3370    -3.947    0
# 212          302001   0.399           0.01260   7    0.0949    -7.526    1
#
#         speechiness    tempo time_signature  valence
# 131747       0.0378   89.231            4/4    0.845
# 195953       0.1110  143.017            4/4    0.797
# 174356       0.9480   79.452            5/4    0.513
# 32714        0.0316  119.974            4/4    0.635
# 212          0.0393   89.972            4/4    0.816

# %%
list_of_time_signatures = df['time_signature'].unique()
for i in range(len(list_of_time_signatures)):
    df.loc[df['time_signature'] == list_of_time_signatures[i], 'time_signature'] = i
df.sample(5)
#list of time signatures
# Out:
#           genre                     artist_name  \
# 70936     Blues                      Gov't Mule
# 34579     Anime                   Ikimonogakari
# 67809   Hip-Hop                    The Internet
# 47169     Blues  Little Anthony & The Imperials
# 182246    Movie               Chorus - Hercules
#
#                              track_name                track_id  popularity  \
# 70936                    Play With Fire  0AZK19CCTadcmXJ83bWkh7          21
# 34579                     Warattetainda  5tWOmNCzjAfdMAvYC1TC13          21
# 67809                          Wanna Be  5GjisoOfsN8qagrax01T4y          68
# 47169   I'm On The Outside (Looking In)  2GMHqFwYnY3OGSvACE1pkE          40
# 182246     A True Hero / A Star Is Born  0Vx07Bg7XsEFk9jBRotQBu          34
#
#         acousticness  danceability  duration_ms  energy  instrumentalness key  \
# 70936         0.6130         0.568       452707   0.693          0.073300   5
# 34579         0.0382         0.548       369853   0.875          0.000000   3
# 67809         0.0674         0.875       267400   0.410          0.037400   4
# 47169         0.8200         0.383       187733   0.282          0.000018   4
# 182246        0.8390         0.168       333667   0.286          0.507000   4
#
#         liveness  loudness mode  speechiness    tempo time_signature  valence
# 70936      0.566    -6.333    0       0.0908  131.011              0   0.5700
# 34579      0.122    -3.001    1       0.0383  157.133              0   0.5340
# 67809      0.106    -6.290    0       0.0571   87.999              0   0.4450
# 47169      0.212   -11.764    1       0.0467  187.090              2   0.2460
# 182246     0.434   -11.353    1       0.0393   87.790              0   0.0982

# %%
df.loc[df['popularity'] < 57, 'popularity'] = 0
df.loc[df['popularity'] >= 57, 'popularity'] = 1
df.loc[df['popularity'] == 1]

# loc is the part having popularity <>= 57 and mode set as 0 and 1
# Out:
#        genre     artist_name  \
# 135      R&B   Mary J. Blige
# 136      R&B         Rihanna
# 137      R&B       Yung Bleu
# 138      R&B        Surfaces
# 139      R&B  Olivia O'Brien
# ...      ...             ...
# 230312  Soul     James Brown
# 230782  Soul    Alex Hepburn
# 230817  Soul    Paloma Faith
# 230946  Soul     James Brown
# 231493  Soul      Simply Red
#
#                                                track_name  \
# 135                            Be Without You - Kendu Mix
# 136                                             Desperado
# 137            Ice On My Baby (feat. Kevin Gates) - Remix
# 138                             Heaven Falls / Fall on Me
# 139                                           Love Myself
# ...                                                   ...
# 230312  Get Up (I Feel Like Being A) Sex Machine - Pts...
# 230782                                        If You Stay
# 230817                        Make Your Own Kind of Music
# 230946                 Papa's Got A Brand New Bag - Pt. 1
# 231493                             The Air That I Breathe
#
#                       track_id  popularity  acousticness  danceability  \
# 135     2YegxR5As7BeQuVp2U6pek           1       0.08300         0.724
# 136     6KFaHC9G178beAp7P0Vi5S           1       0.32300         0.685
# 137     6muW8cSjJ3rusKJ0vH5olw           1       0.06750         0.762
# 138     7yHqOZfsXYlicyoMt62yC6           1       0.36000         0.563
# 139     4XzgjxGKqULifVf7mnDIQK           1       0.59600         0.653
# ...                        ...         ...           ...           ...
# 230312  6hpmTwgNCz81H2bFEREx29           1       0.27300         0.833
# 230782  4sJoIeb8zWYCLHSLM0az3b           1       0.04530         0.719
# 230817  5jsFFhABp2FkasGr4QcQd6           1       0.00862         0.567
# 230946  5aZzmPUv5a2nna9sxBrmpL           1       0.51900         0.775
# 231493  4Sfq2ZuUK9tS66eXqCCKRF           1       0.21000         0.660
#
#         duration_ms  energy  instrumentalness key  liveness  loudness mode  \
# 135          246333   0.689          0.000000   8    0.3040    -5.922    0
# 136          186467   0.610          0.000000   2    0.1020    -5.221    0
# 137          199520   0.520          0.000004   3    0.1140    -5.237    0
# 138          240597   0.366          0.002430  11    0.0955    -6.896    0
# 139          213947   0.621          0.000000  11    0.0811    -5.721    0
# ...             ...     ...               ...  ..       ...       ...  ...
# 230312       318800   0.661          0.000149   9    0.2940    -7.595    0
# 230782       194554   0.702          0.000013  11    0.0662    -4.577    1
# 230817       163840   0.753          0.001830   5    0.1270    -4.823    1
# 230946       128973   0.725          0.054100   5    0.0944    -8.369    1
# 231493       262827   0.560          0.000040   2    0.0974    -8.894    1
#
#         speechiness    tempo time_signature  valence
# 135          0.1350  146.496              0   0.6930
# 136          0.0439   94.384              2   0.3230
# 137          0.0959   75.047              0   0.0862
# 138          0.1210   85.352              0   0.7680
# 139          0.0409  100.006              0   0.4660
# ...             ...      ...            ...      ...
# 230312       0.1010  108.314              0   0.8580
# 230782       0.0357  116.938              0   0.6130
# 230817       0.0406  120.098              0   0.5660
# 230946       0.0944  129.681              0   0.9140
# 231493       0.0287   89.505              0   0.6410
#
# [49104 rows x 18 columns]

# %%
df
# Out:
#         genre               artist_name                        track_name  \
# 0       Movie            Henri Salvador       C'est beau de faire un Show
# 1       Movie         Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2       Movie           Joseph Williams    Don't Let Me Be Lonely Tonight
# 3       Movie            Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4       Movie              Fabien Nataf                         Ouverture
# ...       ...                       ...                               ...
# 232720   Soul                     Slave                      Son Of Slide
# 232721   Soul  Jr Thomas & The Volcanos                      Burning Fire
# 232722   Soul              Muddy Waters    (I'm Your) Hoochie Coochie Man
# 232723   Soul                   R.LUM.R                     With My Words
# 232724   Soul            Mint Condition    You Don't Have To Hurt No More
#
#                       track_id  popularity  acousticness  danceability  \
# 0       0BRjO6ga9RKCKjfDqeFgWV           0       0.61100         0.389
# 1       0BjC1NfoEOOusryehmNudP           0       0.24600         0.590
# 2       0CoSDzoNIKCRs124s9uTVy           0       0.95200         0.663
# 3       0Gc6TVm52BwZD07Ki6tIvf           0       0.70300         0.240
# 4       0IuslXpMROHdEPvSl1fTQK           0       0.95000         0.331
# ...                        ...         ...           ...           ...
# 232720  2XGLdVl7lGeq8ksM6Al7jT           0       0.00384         0.687
# 232721  1qWZdkBl4UVPj9lK6HuuFM           0       0.03290         0.785
# 232722  2ziWXUmQLrXTiYjCg2fZ2t           0       0.90100         0.517
# 232723  6EFsue2YbIG4Qkq8Zr9Rir           0       0.26200         0.745
# 232724  34XO9RwPMKjbvRry54QzWn           0       0.09730         0.758
#
#         duration_ms  energy  instrumentalness key  liveness  loudness mode  \
# 0             99373   0.910          0.000000   0    0.3460    -1.828    1
# 1            137373   0.737          0.000000   1    0.1510    -5.559    0
# 2            170267   0.131          0.000000   2    0.1030   -13.879    0
# 3            152427   0.326          0.000000   0    0.0985   -12.178    1
# 4             82625   0.225          0.123000   3    0.2020   -21.150    1
# ...             ...     ...               ...  ..       ...       ...  ...
# 232720       326240   0.714          0.544000   8    0.0845   -10.626    1
# 232721       282447   0.683          0.000880   5    0.2370    -6.944    0
# 232722       166960   0.419          0.000000   8    0.0945    -8.282    1
# 232723       222442   0.704          0.000000  10    0.3330    -7.137    1
# 232724       323027   0.470          0.000049   7    0.0836    -6.708    0
#
#         speechiness    tempo time_signature  valence
# 0            0.0525  166.969              0    0.814
# 1            0.0868  174.003              0    0.816
# 2            0.0362   99.488              1    0.368
# 3            0.0395  171.758              0    0.227
# 4            0.0456  140.576              0    0.390
# ...             ...      ...            ...      ...
# 232720       0.0316  115.542              0    0.962
# 232721       0.0337  113.830              0    0.969
# 232722       0.1480   84.135              0    0.813
# 232723       0.1460  100.031              0    0.489
# 232724       0.0287  113.897              0    0.479
#
# [232725 rows x 18 columns]

# %%
le = LabelEncoder()
df["track_name"] = le.fit_transform(df["track_name"])

# %%
df
# Out:
#         genre               artist_name  track_name                track_id  \
# 0       Movie            Henri Salvador       18348  0BRjO6ga9RKCKjfDqeFgWV
# 1       Movie         Martin & les fées       92963  0BjC1NfoEOOusryehmNudP
# 2       Movie           Joseph Williams       32194  0CoSDzoNIKCRs124s9uTVy
# 3       Movie            Henri Salvador       30998  0Gc6TVm52BwZD07Ki6tIvf
# 4       Movie              Fabien Nataf       90793  0IuslXpMROHdEPvSl1fTQK
# ...       ...                       ...         ...                     ...
# 232720   Soul                     Slave      111440  2XGLdVl7lGeq8ksM6Al7jT
# 232721   Soul  Jr Thomas & The Volcanos       17957  1qWZdkBl4UVPj9lK6HuuFM
# 232722   Soul              Muddy Waters         431  2ziWXUmQLrXTiYjCg2fZ2t
# 232723   Soul                   R.LUM.R      141395  6EFsue2YbIG4Qkq8Zr9Rir
# 232724   Soul            Mint Condition      143401  34XO9RwPMKjbvRry54QzWn
#
#         popularity  acousticness  danceability  duration_ms  energy  \
# 0                0       0.61100         0.389        99373   0.910
# 1                0       0.24600         0.590       137373   0.737
# 2                0       0.95200         0.663       170267   0.131
# 3                0       0.70300         0.240       152427   0.326
# 4                0       0.95000         0.331        82625   0.225
# ...            ...           ...           ...          ...     ...
# 232720           0       0.00384         0.687       326240   0.714
# 232721           0       0.03290         0.785       282447   0.683
# 232722           0       0.90100         0.517       166960   0.419
# 232723           0       0.26200         0.745       222442   0.704
# 232724           0       0.09730         0.758       323027   0.470
#
#         instrumentalness key  liveness  loudness mode  speechiness    tempo  \
# 0               0.000000   0    0.3460    -1.828    1       0.0525  166.969
# 1               0.000000   1    0.1510    -5.559    0       0.0868  174.003
# 2               0.000000   2    0.1030   -13.879    0       0.0362   99.488
# 3               0.000000   0    0.0985   -12.178    1       0.0395  171.758
# 4               0.123000   3    0.2020   -21.150    1       0.0456  140.576
# ...                  ...  ..       ...       ...  ...          ...      ...
# 232720          0.544000   8    0.0845   -10.626    1       0.0316  115.542
# 232721          0.000880   5    0.2370    -6.944    0       0.0337  113.830
# 232722          0.000000   8    0.0945    -8.282    1       0.1480   84.135
# 232723          0.000000  10    0.3330    -7.137    1       0.1460  100.031
# 232724          0.000049   7    0.0836    -6.708    0       0.0287  113.897
#
#        time_signature  valence
# 0                   0    0.814
# 1                   0    0.816
# 2                   1    0.368
# 3                   0    0.227
# 4                   0    0.390
# ...               ...      ...
# 232720              0    0.962
# 232721              0    0.969
# 232722              0    0.813
# 232723              0    0.489
# 232724              0    0.479
#
# [232725 rows x 18 columns]

# %% [markdown]
# ## MODEL FITTING AND PREDICTING

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC, LinearSVC
from xgboost import XGBClassifier

from sklearn.metrics import make_scorer, accuracy_score, roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# %%
#Features
features = ["acousticness", "danceability", "duration_ms", "energy", "instrumentalness", "key", "liveness",
            "mode", "speechiness", "tempo", "time_signature", "valence"]

# %%
#train and test split
training = df.sample(frac = 0.8,random_state = 420)
X_train = training[features]
y_train = training['popularity']
X_test = df.drop(training.index)[features]

# %%
#adding validation dataset
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size = 0.2, random_state = 420)

# %% [markdown]
# #### LOGISTIC REGRESSION

# %%
LR_Model = LogisticRegression()
#X_train.dropna()
LR_Model.fit(X_train, y_train)
LR_Predict = LR_Model.predict(X_valid)
LR_Accuracy = accuracy_score(y_valid, LR_Predict)
print("Accuracy: " + str(LR_Accuracy))

LR_AUC = roc_auc_score(y_valid, LR_Predict)
print("AUC: " + str(LR_AUC))
# Out:
# Accuracy: 0.7895316360511333
# AUC: 0.5

# %% [markdown]
# ## RANDOM FOREST

# %%
RFC_Model = RandomForestClassifier()
RFC_Model.fit(X_train, y_train)
RFC_Predict = RFC_Model.predict(X_valid)
RFC_Accuracy = accuracy_score(y_valid, RFC_Predict)
print("Accuracy: " + str(RFC_Accuracy))

RFC_AUC = roc_auc_score(y_valid, RFC_Predict)
print("AUC: " + str(RFC_AUC))
# Out:
# Accuracy: 0.9211784294768504
# AUC: 0.832680847696143

# %% [markdown]
# ## KNN (K-NEAREST NEIGHBOURS)

# %%
KNN_Model = KNeighborsClassifier()
KNN_Model.fit(X_train, y_train)
KNN_Predict = KNN_Model.predict(X_valid)
KNN_Accuracy = accuracy_score(y_valid, KNN_Predict)
print("Accuracy: " + str(KNN_Accuracy))

KNN_AUC = roc_auc_score(y_valid, KNN_Predict)
print("AUC: " + str(KNN_AUC))
# Out:
# Accuracy: 0.7735524760983994
# AUC: 0.6154249990048827

# %% [markdown]
# ## DECISION TREE

# %%
DT_Model = DecisionTreeClassifier()
DT_Model.fit(X_train, y_train)
DT_Predict = DT_Model.predict(X_valid)
DT_Accuracy = accuracy_score(y_valid, DT_Predict)
print("Accuracy: " + str(DT_Accuracy))

DT_AUC = roc_auc_score(y_valid, DT_Predict)
print("AUC: " + str(DT_AUC))
# Out:
# Accuracy: 0.851648941884198
# AUC: 0.811343120745206

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (1.7.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.10.1)

# %%
import xgboost

# %% [markdown]
# #### LSVC (LINEAR SUPPORT VECTOR CLASSIFICATION)

# %%
training_LSVC = training.sample(10000)
X_train_LSVC = training_LSVC[features]
y_train_LSVC = training_LSVC['popularity']
X_test_LSVC = df.drop(training_LSVC.index)[features]
X_train_LSVC, X_valid_LSVC, y_train_LSVC, y_valid_LSVC = train_test_split(
    X_train_LSVC, y_train_LSVC, test_size = 0.2, random_state = 420)

# %%
LSVC_Model = DecisionTreeClassifier()
LSVC_Model.fit(X_train_LSVC, y_train_LSVC)
LSVC_Predict = LSVC_Model.predict(X_valid_LSVC)
LSVC_Accuracy = accuracy_score(y_valid_LSVC, LSVC_Predict)
print("Accuracy: " + str(LSVC_Accuracy))

LSVC_AUC = roc_auc_score(y_valid_LSVC, LSVC_Predict)
print("AUC: " + str(LSVC_AUC))
# Out:
# Accuracy: 0.7155
# AUC: 0.5797478522850692

# %% [markdown]
# #### VISUALISING THE PERFORMANCE OF EACH OF THE MODELS

# %%
model_performance_accuracy = pd.DataFrame({'Model': ['LogisticRegression',
                                                      'RandomForestClassifier',
                                                      'KNeighborsClassifier',
                                                      'DecisionTreeClassifier',
                                                      'LinearSVC'
                            ],
                                            'Accuracy': [LR_Accuracy,
                                                         RFC_Accuracy,
                                                         KNN_Accuracy,
                                                         DT_Accuracy,
                                                         LSVC_Accuracy
                                                         ]})

model_performance_AUC = pd.DataFrame({'Model': ['LogisticRegression',
                                                      'RandomForestClassifier',
                                                      'KNeighborsClassifier',
                                                      'DecisionTreeClassifier',
                                                      'LinearSVC',
                                                      ],
                                            'AUC': [LR_AUC,
                                                         RFC_AUC,
                                                         KNN_AUC,
                                                         DT_AUC,
                                                         LSVC_AUC
                                                         ]})

# %%
model_performance_accuracy.sort_values(by = "Accuracy", ascending = False)
# WE CAN ALSO SORT ACCORDING TO THE AUC WHICH MEANS AREA UNDER CURVE
# Out:
#                     Model  Accuracy
# 1  RandomForestClassifier  0.921178
# 3  DecisionTreeClassifier  0.851649
# 0      LogisticRegression  0.789532
# 2    KNeighborsClassifier  0.773552
# 4               LinearSVC  0.715500

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
df
# Out:
#         genre               artist_name  track_name                track_id  \
# 0       Movie            Henri Salvador       18348  0BRjO6ga9RKCKjfDqeFgWV
# 1       Movie         Martin & les fées       92963  0BjC1NfoEOOusryehmNudP
# 2       Movie           Joseph Williams       32194  0CoSDzoNIKCRs124s9uTVy
# 3       Movie            Henri Salvador       30998  0Gc6TVm52BwZD07Ki6tIvf
# 4       Movie              Fabien Nataf       90793  0IuslXpMROHdEPvSl1fTQK
# ...       ...                       ...         ...                     ...
# 232720   Soul                     Slave      111440  2XGLdVl7lGeq8ksM6Al7jT
# 232721   Soul  Jr Thomas & The Volcanos       17957  1qWZdkBl4UVPj9lK6HuuFM
# 232722   Soul              Muddy Waters         431  2ziWXUmQLrXTiYjCg2fZ2t
# 232723   Soul                   R.LUM.R      141395  6EFsue2YbIG4Qkq8Zr9Rir
# 232724   Soul            Mint Condition      143401  34XO9RwPMKjbvRry54QzWn
#
#         popularity  acousticness  danceability  duration_ms  energy  \
# 0                0       0.61100         0.389        99373   0.910
# 1                0       0.24600         0.590       137373   0.737
# 2                0       0.95200         0.663       170267   0.131
# 3                0       0.70300         0.240       152427   0.326
# 4                0       0.95000         0.331        82625   0.225
# ...            ...           ...           ...          ...     ...
# 232720           0       0.00384         0.687       326240   0.714
# 232721           0       0.03290         0.785       282447   0.683
# 232722           0       0.90100         0.517       166960   0.419
# 232723           0       0.26200         0.745       222442   0.704
# 232724           0       0.09730         0.758       323027   0.470
#
#         instrumentalness key  liveness  loudness mode  speechiness    tempo  \
# 0               0.000000   0    0.3460    -1.828    1       0.0525  166.969
# 1               0.000000   1    0.1510    -5.559    0       0.0868  174.003
# 2               0.000000   2    0.1030   -13.879    0       0.0362   99.488
# 3               0.000000   0    0.0985   -12.178    1       0.0395  171.758
# 4               0.123000   3    0.2020   -21.150    1       0.0456  140.576
# ...                  ...  ..       ...       ...  ...          ...      ...
# 232720          0.544000   8    0.0845   -10.626    1       0.0316  115.542
# 232721          0.000880   5    0.2370    -6.944    0       0.0337  113.830
# 232722          0.000000   8    0.0945    -8.282    1       0.1480   84.135
# 232723          0.000000  10    0.3330    -7.137    1       0.1460  100.031
# 232724          0.000049   7    0.0836    -6.708    0       0.0287  113.897
#
#        time_signature  valence
# 0                   0    0.814
# 1                   0    0.816
# 2                   1    0.368
# 3                   0    0.227
# 4                   0    0.390
# ...               ...      ...
# 232720              0    0.962
# 232721              0    0.969
# 232722              0    0.813
# 232723              0    0.489
# 232724              0    0.479
#
# [232725 rows x 18 columns]

# %% [markdown]
# ##### PRINTING THE PREDICTION FOR THE TOP 100 SONGS USING RANDOM FOREST ALGO

# %%
#print("Random forest top 100 songs:", (le.inverse_transform(RFC_Predict[:100])))
#RFC_Predict.size
#top_100_indices = df[df["RFC_Predict"] == 1].index[:100]
import numpy as np

# %%
top_100_indices = np.argsort(RFC_Predict)[::-1][:100]

# %%
top_100_track_names = [df["track_name"][i] for i in top_100_indices]

# %%
print(le.inverse_transform(top_100_track_names))
# Out:
# ['Stars' 'Makes No Difference' 'Forever' 'If You Ask Me To'
#  'Promises, Promises' 'Count Me Out' 'Easy' 'Uno' 'Ever (Foreign Flag)'
#  'Black Mags' 'My Good Gal' 'Paranoid Android - Remastered'
#  'Before the Throne of God Above' 'Our Apartment' "Where There's Smoke"
#  'Tired Of You' 'Kalopsia' 'Good Life' 'Gently' 'The Shoebox'
#  'If This Bus Could Talk' 'Bleed Out' 'Guarantees'
#  "What Sober Couldn't Say" 'When You Were Mine' 'Hello Operator'
#  'Dear Old Sun' 'Stand By Me' 'Soothe Your Pain (Produced By Sinima)'
#  'Asphyxia' "Don't Think Twice" 'Touch off' 'Melba from Melbourne' 'Signs'
#  "Don't Tell Mama" 'The Way It Goes' 'Bring My Baby Back' "A Woman's Love"
#  'Weisses Fleisch' 'Outlaw Ways' 'The Pressure Is On (Live)' 'Whiskey Man'
#  'Pissed Off and Mad About It' 'Secret - Acoustic'
#  'KAYTRANADA_WAITIN_115 BPM' 'Red Giant' 'BALDWIN' 'Either Way'
#  'Be Prepared For Hell' 'Sex Yeah' 'Hardest Of Hearts' 'Father'
#  'Sweet Tooth' 'Runaway' 'Remind Me - Radio Edit' 'The Widow' 'Beef Rap'
#  'Breaking Inside (feat. Lzzy Hale of Halestorm)' 'Sugaree'
#  'Young And Wild' 'Desperation' 'This Time' 'Antichrist Superstar'
#  'Made Of Stone' 'Running Blind - Acoustic' 'My Disaster' 'Famous'
#  'Got The Time' 'DJ Tonight' 'Clattanoia' 'Mexican Sun'
#  'Counter Attack-Mankind' 'Let It Go' 'Gotta Quit Drinkin' 'Shipwrecked'
#  'Damn, Do I Think About You' 'Moon & Bouquet' 'Overfly' 'Lamp'
#  '"DEVILS NEVER CRY"(スタッフロール)'
#  'One\u200b-\u200bWinged Angel (Final Fantasy VII)' 'The Glory Days'
#  'Spirited Away - The Sixth Station' 'White Fence' 'God Only Knows'
#  'Fly Me To The Moon - Yoko Takahashi Acid Bossa Version'
#  'The Pain Of Loving You - Remastered' 'Euterpe - 2017 Remastered'
#  'Seminole Wind - Live At Amalie Arena, Tampa, FL / May 4, 2017'
#  'Wylin (feat. Bubba Sparxxx)' 'RE:' 'Hurricanes and Hand Grenades'
#  'No Saint' 'I Wanna Be In The Cavalry' 'Pretender'
#  "I've Been Everywhere - Remastered" 'Last Stardust' 'DetaramE KiddinG'
#  'Roll on Mississippi' 'Priorities']

# %% [markdown]
# ##### PRINTING THE TOP 100 SONG NAMES USING LOGISTIC REGRESSION

# %%
#LR_Predict
top_100_indices = np.argsort(LR_Predict)[::-1][:100]
top_100_track_names = [df["track_name"][i] for i in top_100_indices]
print(le.inverse_transform(top_100_track_names))
# Out:
# ['Vikings' 'Pumpin Blood - The Jane Doze Remix' 'Sarah (Bonus Track)'
#  'Hexagram' 'Crossing The Frame' 'Bold' 'Stoned, Alone' 'Rebel Yell'
#  'NO EXCUSES (Acoustic Live)' 'Virtue' 'Perfect Sweet Blue' 'Death Dance'
#  'Song In My Soul (feat. Hollyn)' 'Black Sunday' 'In Christ Alone'
#  'Our Loved Ones' 'Resurrecting - Live' 'Runaway' 'Lifted Up (1985)'
#  "I Don't Care Anymore (Acoustic)" 'Kitty' 'Time After All' 'Found & Lost'
#  "We Won't Back Down" 'Lost Cause' '1-800 Suicide' 'Blood on the Ground'
#  "You Don't Care for Me Enough to Cry" 'buproprion' 'Wild Heart'
#  "'Til the City's On Fire" 'Holdin Me Back' 'Pretend' 'Only King Forever'
#  'Chasing The First Time' 'Brazilian Soul (feat. Sofi Tukker)'
#  'What Got In The Way' 'Runnin' 'Turn It Up' 'Chaos and Clothes'
#  'Hurricane Drunk' 'Wanderer' "Can't Do Without You"
#  "Song To Sing When I'm Lonely" 'Boss' 'LIES GREED MISERY'
#  'Thinking Of You' 'Dirty Money' 'After Hours (Extended Euro Mix)'
#  'Summer On Lock (feat. Pusha T, Jadakiss, Fabolous & Agent Sasco' 'Crisp'
#  'Total Football' 'Folk-Metaphysics' "Bitchin' Camaro" 'UNSTATUS QUO'
#  'Trainwreck' 'Spectrum' 'Not The Only One' 'Recuring Dream' 'Prayers'
#  'I Hope You Rot' 'Qwerty' 'Forsaken' 'WE GOT THE BISCUITS' 'Landslide'
#  'Triple Threat' 'Bubbles' 'Sofa King'
#  'kometostai.aintreallynootherwaytoputitro' 'Destroyer'
#  "You're Not Stubborn" 'El Son del Dolor' 'Make Me Cry'
#  'All Night - Unfinished' 'Crush - Unfinished' "Livin' Proof" 'The Hop'
#  'War Is The Answer' 'Monster' 'With You' 'Sentimento Original' 'Criminal'
#  'Needle In The Hay' 'Cynics & Critics'
#  'Skin And Bones - Live at the Pantages Theatre, Los Angeles, CA - August 2006'
#  'Outside Sublime' 'Level' 'Cinco De Mayo Shit Show' 'En el 2000'
#  'When They Call My Name'
#  'You Never Knew My Mind (Johnny Cash: Forever Words)' 'Black Label'
#  'Top of the World' 'Push' 'Leap Of Faith' "I'd Have to Be Crazy" 'Loser.'
#  'Morning Song' 'LEAVE ME ALONE' 'Pogo']

# %% [markdown]
# #### PRINTING THE TOP 100 SONG NAMES USING DECISION TREE ALGO

# %%
#DT_Predict
top_100_indices = np.argsort(DT_Predict)[::-1][:100]
top_100_track_names = [df["track_name"][i] for i in top_100_indices]
print(le.inverse_transform(top_100_track_names))
# Out:
# ['Stars' 'The Right Type' 'Down by the River' 'Wide Open (feat. Cherub)'
#  'Sweet Surrender' 'Nashville Blues - Live' 'Close Call'
#  'Freedom to Stay - Live' 'Time' 'Strangeulation I'
#  '...And The World Laughs With You' 'A Place to Fall Apart'
#  'Fly Me Courageous' 'stevie' 'Space Jelly' 'Forever Together'
#  'Pull the Plug - feat. Kool Keith' 'I Think Of You'
#  "Look What You've Done to Me" 'Come to Me' 'Memories We Share'
#  'I Love You' 'Alpha Beta Gaga' 'Swinging Doors' 'Back Again'
#  'Pretty Little Adriana' "Likin' Love Songs" 'Wompum' 'First Love Song'
#  'Super Hot' 'On My Knees (feat. Michael Kiwanuka)' 'Salvation Song'
#  'Sticker Peck Out' 'Pop Art Blue' 'Ghetto Matrix' 'Heartbeats - Live'
#  'Polaris' 'Frankenstein' 'Melody Day - Four Tet Remix' 'Hell Motel'
#  'Lose Ya Love' 'Wipe the Slate Clean' 'Take Me Away'
#  'Little Green Apples - Single Version' 'De Lejos' 'Liberty Flute'
#  'EXHALE' "I Can't Do That Anymore" 'Rock You Sweet' 'Schizophrenia'
#  'Marley' 'Her Name Is...' 'Tequila - Maverikk Remix' 'Siku'
#  'Leave or Stay (feat. Simona Brezanova)' 'What Color Is Your Sky'
#  'She Will Be Free' 'A Name In This Town' 'Out Of My Bones'
#  'What Hurts The Most - Remastered Version'
#  'Tequila - Sylvain Armand Remix' 'Call It a Night'
#  'Shots & Squats - SoMo Vocal Mix' 'Audio, Video, Disco.'
#  'I Am Invincible' 'Focus On Sight' 'Maximum Living On A Minimum Wage'
#  '2012 - 4B Remix' 'The Day Is My Enemy - Liam H Remix feat. Dope D.O.D.'
#  'Home For The Holidays' "Can't Be Really Gone" 'Drunk Girls' 'Belfast'
#  'Em Pessoa' 'Redneck Rave Anthem (feat. Upchurch the Redneck)'
#  'White Cyclosa' 'Allow Me' 'Aftermath' 'Strangeulation Vol. II Cypher I'
#  'Butterfly' 'Blast Off' 'Time + Space' 'Giant' 'Who Wants to Rock'
#  'Alice' "I Can't See Me Without You" 'Let Me Love You - Sean Paul Remix'
#  'Shakedown - LOUDPVCK Remix' 'What About Georgia?'
#  '(What This World Needs Is) A Few More Rednecks' 'That Song In My Head'
#  'Athene' 'Somewhere in the Middle (Between Right & Wrong)'
#  'Would It Be Wrong' 'Unison' 'Silence On The Wall'
#  'Southern Sun - DJ Tiësto Remix' 'Poor Boy' 'Flashback' "It's All Good"]

# %% [markdown]
# #### TOP 100 SONG NAMES BY THE LSVC

# %%
#LSVC_Predict
top_100_indices = np.argsort(LSVC_Predict)[::-1][:100]
top_100_track_names = [df["track_name"][i] for i in top_100_indices]
print(le.inverse_transform(top_100_track_names))
# Out:
# ['Music' 'Le clochard' 'Symphony No.4 In E Minor Op.98 : II. Andante'
#  'Numb' 'Happy?' 'Frou Frou' 'Hindolam' 'I Am the Highway' 'Mann Biachen'
#  'MOOO!' 'Aladin 4' 'Nights' 'Dis moi monsieur Bernard Minet'
#  'But pour Rudy' 'Alien Boy' 'Ivy' 'When Legends Rise' 'Tongue Tied'
#  'SLOW DANCING IN THE DARK' 'All Apologies'
#  'Yia se ghlikia patridha (For You Sweet Motherland)' 'Indiciblement'
#  'I Alone' 'Anywhere But Here' 'Le conteur, Pt. 2' 'Enemies' 'My Body'
#  'Go' 'Psycho' 'My Mistake' 'Cowboys from Hell' 'In The End'
#  'Black Hole Sun' 'I 25 martiou (The 25th of March)' 'YEAH RIGHT'
#  'New Slang' 'Diving Duck Blues' 'Prayer Of The Refugee' 'Wolfcat'
#  'Les yeux des Muchachos' 'Tout est possible (par Lisa Angell)'
#  'Too Close' 'The Entertainer' 'Confidently Lost'
#  'Oh Devil - Radio Version'
#  'Maître Pierre : Tableau II - Très illustres docteurs'
#  "L'aiguille creuse - Partie 1" 'Man in the Box'
#  "You're Gonna Go Far, Kid" 'How You Remind Me' 'Way Down We Go' 'Drive'
#  'Cecilia' 'Pink + White' 'Sanctuary' 'Headstrong' 'The High Road'
#  "Toi, l'avenir du monde" 'Janet' 'Control' 'Rollerblades'
#  'Sukhkarta Dukhharta - Aarti' 'Head Like A Hole' 'Change' 'Toi - live'
#  "Parler d'amour" 'Beyond the Sea' 'Mudshovel' 'Runaway Train'
#  'Sweet Disaster' 'Semi-Charmed Life' 'Eliza' "Qh'ech que ch'est qu'cha?"
#  'Drowning' 'Things That Break' 'Love Me' 'Overnight Celebrity' 'Sticky'
#  'Just a Friend 2002 - Radio Edit' "Can't Go Back" 'Sunday In The South'
#  'Love Me Now' "It's My Dog Birthday" 'The Strawberry Roan' 'Reckless'
#  'Confessions Part II - Confessions Special Edition Version'
#  'Blue Tacoma - Recorded at Sound Stage Studios Nashville' 'Even If'
#  'Glitter & Gold' 'Wild Irish Roses' "Le sourire d'Anaëlle" 'About To'
#  'Song 2 - 2012 Remaster' 'Unfair' 'Make You Feel' 'U Up'
#  'The Road Goes On Forever' 'Vaquero' 'Du hast'
#  'Tyrant (feat. Jorja Smith)']
